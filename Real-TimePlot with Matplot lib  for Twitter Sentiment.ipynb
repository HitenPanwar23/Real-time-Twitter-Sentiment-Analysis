# %%
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation    ##For realtime plot, we use matplotlib.animation
# %matplotlib notebook

# %%
plt.style.use('fivethirtyeight')

# %%
frame_len = 10000

fig = plt.figure(figsize=(9,6))

def animate(i):
    data = pd.read_csv('sentiment.csv')
    y1 = data['Narendra Modi']
    y2 = data['Rahul Gandhi']

    if len(y1)<=frame_len:
        plt.cla() 
        plt.plot(y1, label='Narendra Modi')
        plt.plot(y2, label='Rahul Gandhi')
    else:
        plt.cla() 
        plt.plot(y1[-frame_len: ], label='Narendra Modi') 
        plt.plot(y2[-frame_len: ], label='Rahul Gandhi') 
        
    plt.legend(loc='upper left')
    plt.tight_layout()
    
ani=FuncAnimation(plt.gcf(), animate, interval=1000)
# Out:
# <img src="data:image/png;base64,..." width="900">
